# %% [markdown]
# # Single tool run

# %%
# !nextflow run main.nf --repo_url https://github.com/cytomining/CytoTable
# Out:
#  N E X T F L O W   ~  version 25.04.6
#
# Launching `main.nf` [extravagant_keller] DSL2 - revision: 5d709b8730
#
# ERROR ~ ERROR: synapse_agent_id must be provided.
#
#  -- Check script 'main.nf' at line: 58 or see '.nextflow.log' file for more details

# %%
# !nextflow run main.nf --repo_url https://github.com/cytomining/CytoTable --synapse_agent_id LOWYSX3QSQ
# Out:
#  N E X T F L O W   ~  version 25.04.6
#
# Launching `main.nf` [zen_gilbert] DSL2 - revision: 5d709b8730
#
# ERROR ~ ERROR: Invalid repository URL format: 'https://github.com/cytomining/CytoTable'. Expected format: https://github.com/username/repo.git
#
#  -- Check script 'main.nf' at line: 84 or see '.nextflow.log' file for more details
#
# ERROR ~ ERROR: Invalid repository URL format: 'https://github.com/cytomining/CytoTable'. Expected format: https://github.com/username/repo.git
#
#  -- Check script 'main.nf' at line: 84 or see '.nextflow.log' file for more details

# %%
# !nextflow run main.nf --repo_url https://github.com/cytomining/CytoTable.git --synapse_agent_id LOWYSX3QSQ
# Out:
#  N E X T F L O W   ~  version 25.04.6
#
# Launching `main.nf` [small_hugle] DSL2 - revision: 5d709b8730
#
# executor >  local (1)
# [83/504595] ProcessRepo (1)     | 0 of 1
# [-        ] RunAlmanack         -
# [-        ] TestExecutor        -
# [-        ] AnalyzeJOSSCriteria -
# [-        ] AIAnalysis          -
#
# executor >  local (1)
# [83/504595] ProcessRepo (1)     | 0 of 1
# [-        ] RunAlmanack         -
# [-        ] TestExecutor        -
# [-        ] AnalyzeJOSSCriteria -
# [-        ] AIAnalysis          -
#
# executor >  local (3)
# [83/504595] ProcessRepo (1)     | 1 of 1 ✔
# [6c/53a0c3] RunAlmanack (1)     | 0 of 1
# [35/8ebf29] TestExecutor (1)    | 0 of 1
# [-        ] AnalyzeJOSSCriteria -
# [-        ] AIAnalysis          -
#
# executor >  local (3)
# [83/504595] ProcessRepo (1)     | 1 of 1 ✔
# [6c/53a0c3] RunAlmanack (1)     | 0 of 1
# [35/8ebf29] TestExecutor (1)    | 1 of 1 ✔
# [-        ] AnalyzeJOSSCriteria -
# [-        ] AIAnalysis          -
#
# ...

# %%
# !cat results/status_almanack_CytoTable.txt
# Out:
# CytoTable,PASS,PASS,PASS,PASS

# %%
# !cat results/joss_report_CytoTable.json | jq .
# Out:
# {
#   "criteria": {
#     "Statement of Need": {
#       "status": "ok",
#       "score": 0.7,
#       "details": "Found README but statement of need needs improvement"
#     },
#     "Installation Instructions": {
#       "status": "good",
#       "score": 1.0,
#       "details": "Found comprehensive installation instructions"
#     },
#     "Example Usage": {
#       "status": "ok",
#       "score": 0.7,
#       "details": "Found documentation but example usage needs improvement"
#     },
#     "Community Guidelines": {
#       "status": "good",
#       "score": 1.0,
#       "details": "Found both contributing guidelines and code of conduct"
#     },
#     "Tests": {
#       "status": "needs improvement",
#       "score": 0.0,
# ...

# %%
# !cat results/test_results_CytoTable.json | jq .
# Out:
# {
#   "framework": "pytest",
#   "status": "FAIL",
#   "total_tests": 0,
#   "passed": 0,
#   "failed": 0,
#   "output": "",
#   "error": "ImportError while loading conftest '/Users/buntend/Documents/work/cckp-toolkit-workflow/work/83/5045956892a778a5b31e7f76edcdb8/repo/tests/conftest.py'.\ntests/conftest.py:13: in <module>\n    import duckdb\nE   ModuleNotFoundError: No module named 'duckdb'\n"
# }

# %%
# !cat results/CytoTable_almanack_Results.json | jq .
# Out:
# [
#   {
#     "name": "repo-path",
#     "id": "SGA-META-0001",
#     "result-type": "str",
#     "sustainability_correlation": 0,
#     "description": "Repository path (local directory).",
#     "correction_guidance": null,
#     "result": "/Users/buntend/Documents/work/cckp-toolkit-workflow/work/83/5045956892a778a5b31e7f76edcdb8/repo"
#   },
#   {
#     "name": "repo-commits",
#     "id": "SGA-META-0002",
#     "result-type": "int",
#     "sustainability_correlation": 0,
#     "description": "Total number of commits for the repository.",
#     "correction_guidance": null,
#     "result": 269
#   },
#   {
#     "name": "repo-file-count",
#     "id": "SGA-META-0003",
#     "result-type": "int",
#     "sustainability_correlation": 0,
#     "description": "Total number of files tracked within the repository.",
#     "correction_guidance": null,
#     "result": 170
#   },
#   {
#     "name": "repo-commit-time-range",
#     "id": "SGA-META-0004",
#     "result-type": "tuple",
# ...
